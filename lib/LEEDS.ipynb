# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
This experiment was created using PsychoPy3 Experiment Builder (v2022.2.4),
    on October 02, 2023, at 07:46
If you publish work using this script the most relevant publication is:

    Peirce J, Gray JR, Simpson S, MacAskill M, Höchenberger R, Sogo H, Kastman E, Lindeløv JK. (2019) 
        PsychoPy2: Experiments in behavior made easy Behav Res 51: 195. 
        https://doi.org/10.3758/s13428-018-01193-y

"""

# --- Import packages ---
from psychopy import locale_setup
from psychopy import prefs
from psychopy import sound, gui, visual, core, data, event, logging, clock, colors, layout
from psychopy.constants import (NOT_STARTED, STARTED, PLAYING, PAUSED,
                                STOPPED, FINISHED, PRESSED, RELEASED, FOREVER)

import numpy as np  # whole numpy lib is available, prepend 'np.'
from numpy import (sin, cos, tan, log, log10, pi, average,
                   sqrt, std, deg2rad, rad2deg, linspace, asarray)
from numpy.random import random, randint, normal, shuffle, choice as randchoice
import os  # handy system and path functions
import sys  # to get file system encoding

import psychopy.iohub as io
from psychopy.hardware import keyboard

# Run 'Before Experiment' code from code
#if Scoring=='+':
#    thisExp.addData('score',rating.getRating())
#elif Scoring=='-':
#    thisExp.addData('score',6-rating.getRating())

# Store info about the experiment session
psychopyVersion = '2022.2.4'
expName = 'LEEDS'  # from the Builder filename that created this script
expInfo = {
    'Study': '1',
    'Subject': '0',
    'Block': '1',
}
# --- Show participant info dialog --
dlg = gui.DlgFromDict(dictionary=expInfo, sortKeys=False, title=expName)
if dlg.OK == False:
    core.quit()  # user pressed cancel
expInfo['date'] = data.getDateStr()  # add a simple timestamp
expInfo['expName'] = expName
expInfo['psychopyVersion'] = psychopyVersion

# NC 28.09: trying to correct the error "can't find __File__"
# Replace 'your_script.py' with the actual name of your Python script if needed
script_filename = 'LEEDS.py'

# Specify the directory where your script is located
script_directory = 'C:\\Users\\noemi\\Desktop\\task\\'

# Combine the directory and script filename to get the full path
this_script_path = os.path.join(script_directory, script_filename)

# Get the directory containing the script
_thisDir = os.path.dirname(this_script_path)

os.chdir(_thisDir)

# Data file name stem = absolute path + name; later add .psyexp, .csv, .log, etc
filename = _thisDir + os.sep + u'data/%s_%s_%s' % (expInfo['Subject'], expName, expInfo['date'])

# An ExperimentHandler isn't essential but helps with data saving
thisExp = data.ExperimentHandler(name=expName, version='',
    extraInfo=expInfo, runtimeInfo=None,
    originPath='C:\\Users\\noemi\\Documents\\Python_Work\\LEEDS.ipynb',
    savePickle=True, saveWideText=True,
    dataFileName=filename)
# save a log file for detail verbose info
logFile = logging.LogFile(filename+'.log', level=logging.EXP)
logging.console.setLevel(logging.WARNING)  # this outputs to the screen, not a file

endExpNow = False  # flag for 'escape' or other condition => quit the exp
frameTolerance = 0.001  # how close to onset before 'same' frame

# Start Code - component code to be run after the window creation

# --- Setup the Window ---
win = visual.Window(
    size=[1920, 1080], fullscr=True, screen=0, 
    winType='pyglet', allowStencil=False,
    monitor='testMonitor', color=[-1.0000, -1.0000, -1.0000], colorSpace='rgb',
    blendMode='avg', useFBO=True, 
    units='height')
win.mouseVisible = False
# store frame rate of monitor if we can measure it
expInfo['frameRate'] = win.getActualFrameRate()
if expInfo['frameRate'] != None:
    frameDur = 1.0 / round(expInfo['frameRate'])
else:
    frameDur = 1.0 / 60.0  # could not measure, so guess
# --- Setup input devices ---
ioConfig = {}

# Setup iohub keyboard
ioConfig['Keyboard'] = dict(use_keymap='psychopy')

ioSession = '1'
if 'session' in expInfo:
    ioSession = str(expInfo['session'])
ioServer = io.launchHubServer(window=win, **ioConfig)
eyetracker = None

# create a default keyboard (e.g. to check for escape)
defaultKeyboard = keyboard.Keyboard(backend='iohub')

# --- Initialize components for Routine "KeyboardQ" ---
LEEDS_1 = visual.TextStim(win=win, name='LEEDS_1',
    text='LEEDS Fragebogen',
    font='Arial',
    pos=(0,.45), height=0.05, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=0.0);
KeyboardText = visual.TextStim(win=win, name='KeyboardText',
    text='',
    font='Arial',
    pos=(0, .2), height=0.05, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-1.0);
KeyboardAnswer = visual.TextBox2(
     win, text='', font='Arial',
     pos=(0, 0),     letterHeight=0.05,
     size=(None, None), borderWidth=2.0,
     color='white', colorSpace='rgb',
     opacity=None,
     bold=False, italic=False,
     lineSpacing=1.0,
     padding=0.0, alignment='center',
     anchor='center',
     fillColor=None, borderColor=None,
     flipHoriz=False, flipVert=False, languageStyle='LTR',
     editable=True,
     name='KeyboardAnswer',
     autoLog=True,
)
buttonWeiter_1 = visual.ButtonStim(win, 
    text='Weiter', font='Open Sans',
    pos=(0, -.15),
    letterHeight=0.04,
    size=(0.25, 0.1), borderWidth=0.0,
    fillColor=[0,0,0], borderColor='Black',
    color='white', colorSpace='rgb',
    opacity=None,
    bold=True, italic=False,
    padding=None,
    anchor='center',
    name='buttonWeiter_1'
)
buttonWeiter_1.buttonClock = core.Clock()
ContinueBackText_1 = visual.TextStim(win=win, name='ContinueBackText_1',
    text='Tippe deine  Antwort auf der Tastatur ein und bestätige mit Klicken auf "Weiter". Nutze die Richtungstasten um im Text zu manövrieren.',
    font='Arial',
    pos=(0, -.35), height=0.04, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-4.0);

# --- Initialize components for Routine "SliderQ" ---
LEEDS_2 = visual.TextStim(win=win, name='LEEDS_2',
    text='LEEDS Fragebogen',
    font='Arial',
    pos=(0,.45), height=0.05, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=0.0);
Text = visual.TextStim(win=win, name='Text',
    text='',
    font='Arial',
    pos=(0, 0.25), height=0.05, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-1.0);
Slider = visual.Slider(win=win, name='Slider',
    startValue=None, size=None, pos=(0, -0.05), units=None,
    labels=None, ticks=(1, 100), granularity=0.0,
    style='rating', styleTweaks=(), opacity=None,
    labelColor='White', markerColor='White', lineColor='White', colorSpace='rgb',
    font='Arial', labelHeight=0.05,
    flip=False, ori=0.0, depth=-2, readOnly=False)
SliderText1 = visual.TextStim(win=win, name='SliderText1',
    text='',
    font='Arial',
    pos=(-0.5, -.2), height=0.05, wrapWidth=0.45, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-3.0);
SliderText2 = visual.TextStim(win=win, name='SliderText2',
    text='',
    font='Arial',
    pos=(0.5, -.2), height=0.05, wrapWidth=0.35, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-4.0);
buttonWeiter_2 = visual.ButtonStim(win, 
    text='', font='Arial',
    pos=(0, -0.25),
    letterHeight=0.04,
    size=(0.25, 0.1), borderWidth=0.0,
    fillColor=[0,0,0], borderColor='Black',
    color='white', colorSpace='rgb',
    opacity=None,
    bold=True, italic=False,
    padding=None,
    anchor='center',
    name='buttonWeiter_2'
)
buttonWeiter_2.buttonClock = core.Clock()
ContinueBackText_5 = visual.TextStim(win=win, name='ContinueBackText_5',
    text='Bewege den Cursor mit der Maus und bestätige mit der linken Maustaste. Dann klicke auf "Weiter".',
    font='Arial',
    pos=(0, -0.40), height=0.04, wrapWidth=None, ori=0.0, 
    color='white', colorSpace='rgb', opacity=None, 
    languageStyle='LTR',
    depth=-6.0);

# Create some handy timers
globalClock = core.Clock()  # to track the time since experiment started
routineTimer = core.Clock()  # to track time remaining of each (possibly non-slip) routine 

# set up handler to look after randomisation of conditions etc
LeedsKeyboard = data.TrialHandler(nReps=1.0, method='sequential', 
    extraInfo=expInfo, originPath=-1,
    trialList=data.importConditions('LeedsKeyboard.xlsx'),
    seed=None, name='LeedsKeyboard')
thisExp.addLoop(LeedsKeyboard)  # add the loop to the experiment
thisLeedsKeyboard = LeedsKeyboard.trialList[0]  # so we can initialise stimuli with some values
# abbreviate parameter names if possible (e.g. rgb = thisLeedsKeyboard.rgb)
if thisLeedsKeyboard != None:
    for paramName in thisLeedsKeyboard:
        exec('{} = thisLeedsKeyboard[paramName]'.format(paramName))

for thisLeedsKeyboard in LeedsKeyboard:
    currentLoop = LeedsKeyboard
    # abbreviate parameter names if possible (e.g. rgb = thisLeedsKeyboard.rgb)
    if thisLeedsKeyboard != None:
        for paramName in thisLeedsKeyboard:
            exec('{} = thisLeedsKeyboard[paramName]'.format(paramName))
    
    # --- Prepare to start Routine "KeyboardQ" ---
    continueRoutine = True
    routineForceEnded = False
    # update component parameters for each repeat
    KeyboardText.setText(Item)
    KeyboardAnswer.reset()
    KeyboardAnswer.setText(Answer)
    # keep track of which components have finished
    KeyboardQComponents = [LEEDS_1, KeyboardText, KeyboardAnswer, buttonWeiter_1, ContinueBackText_1]
    for thisComponent in KeyboardQComponents:
        thisComponent.tStart = None
        thisComponent.tStop = None
        thisComponent.tStartRefresh = None
        thisComponent.tStopRefresh = None
        if hasattr(thisComponent, 'status'):
            thisComponent.status = NOT_STARTED
    # reset timers
    t = 0
    _timeToFirstFrame = win.getFutureFlipTime(clock="now")
    frameN = -1
    
    # --- Run Routine "KeyboardQ" ---
    while continueRoutine:
        # get current time
        t = routineTimer.getTime()
        tThisFlip = win.getFutureFlipTime(clock=routineTimer)
        tThisFlipGlobal = win.getFutureFlipTime(clock=None)
        frameN = frameN + 1  # number of completed frames (so 0 is the first frame)
        # update/draw components on each frame
        
        # *LEEDS_1* updates
        if LEEDS_1.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            LEEDS_1.frameNStart = frameN  # exact frame index
            LEEDS_1.tStart = t  # local t and not account for scr refresh
            LEEDS_1.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(LEEDS_1, 'tStartRefresh')  # time at next scr refresh
            LEEDS_1.setAutoDraw(True)
        
        # *KeyboardText* updates
        if KeyboardText.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            KeyboardText.frameNStart = frameN  # exact frame index
            KeyboardText.tStart = t  # local t and not account for scr refresh
            KeyboardText.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(KeyboardText, 'tStartRefresh')  # time at next scr refresh
            KeyboardText.setAutoDraw(True)
        
        # *KeyboardAnswer* updates
        if KeyboardAnswer.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            KeyboardAnswer.frameNStart = frameN  # exact frame index
            KeyboardAnswer.tStart = t  # local t and not account for scr refresh
            KeyboardAnswer.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(KeyboardAnswer, 'tStartRefresh')  # time at next scr refresh
            KeyboardAnswer.setAutoDraw(True)
        
        # *buttonWeiter_1* updates
        if buttonWeiter_1.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            buttonWeiter_1.frameNStart = frameN  # exact frame index
            buttonWeiter_1.tStart = t  # local t and not account for scr refresh
            buttonWeiter_1.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(buttonWeiter_1, 'tStartRefresh')  # time at next scr refresh
            buttonWeiter_1.setAutoDraw(True)
        if buttonWeiter_1.status == STARTED:
            # check whether buttonWeiter_1 has been pressed
            if buttonWeiter_1.isClicked:
                if not buttonWeiter_1.wasClicked:
                    buttonWeiter_1.timesOn.append(buttonWeiter_1.buttonClock.getTime()) # store time of first click
                    buttonWeiter_1.timesOff.append(buttonWeiter_1.buttonClock.getTime()) # store time clicked until
                else:
                    buttonWeiter_1.timesOff[-1] = buttonWeiter_1.buttonClock.getTime() # update time clicked until
                if not buttonWeiter_1.wasClicked:
                    continueRoutine = False  # end routine when buttonWeiter_1 is clicked
                    None
                buttonWeiter_1.wasClicked = True  # if buttonWeiter_1 is still clicked next frame, it is not a new click
            else:
                buttonWeiter_1.wasClicked = False  # if buttonWeiter_1 is clicked next frame, it is a new click
        else:
            buttonWeiter_1.wasClicked = False  # if buttonWeiter_1 is clicked next frame, it is a new click
        
        # *ContinueBackText_1* updates
        if ContinueBackText_1.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            ContinueBackText_1.frameNStart = frameN  # exact frame index
            ContinueBackText_1.tStart = t  # local t and not account for scr refresh
            ContinueBackText_1.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(ContinueBackText_1, 'tStartRefresh')  # time at next scr refresh
            ContinueBackText_1.setAutoDraw(True)
        
        # check for quit (typically the Esc key)
        if endExpNow or defaultKeyboard.getKeys(keyList=["escape"]):
            core.quit()
        
        # check if all components have finished
        if not continueRoutine:  # a component has requested a forced-end of Routine
            routineForceEnded = True
            break
        continueRoutine = False  # will revert to True if at least one component still running
        for thisComponent in KeyboardQComponents:
            if hasattr(thisComponent, "status") and thisComponent.status != FINISHED:
                continueRoutine = True
                break  # at least one component has not yet finished
        
        # refresh the screen
        if continueRoutine:  # don't flip if this routine is over or we'll get a blank screen
            win.flip()
    
    # --- Ending Routine "KeyboardQ" ---
    for thisComponent in KeyboardQComponents:
        if hasattr(thisComponent, "setAutoDraw"):
            thisComponent.setAutoDraw(False)
    LeedsKeyboard.addData('KeyboardAnswer.text',KeyboardAnswer.text)
    # the Routine "KeyboardQ" was not non-slip safe, so reset the non-slip timer
    routineTimer.reset()
    thisExp.nextEntry()
    
# completed 1.0 repeats of 'LeedsKeyboard'

# get names of stimulus parameters
if LeedsKeyboard.trialList in ([], [None], None):
    params = []
else:
    params = LeedsKeyboard.trialList[0].keys()
# save data for this loop
LeedsKeyboard.saveAsExcel(filename + '.xlsx', sheetName='LeedsKeyboard',
    stimOut=params,
    dataOut=['n','all_mean','all_std', 'all_raw'])

# set up handler to look after randomisation of conditions etc
LeedsSlider = data.TrialHandler(nReps=1.0, method='sequential', 
    extraInfo=expInfo, originPath=-1,
    trialList=data.importConditions('LeedsSlider.xlsx'),
    seed=None, name='LeedsSlider')
thisExp.addLoop(LeedsSlider)  # add the loop to the experiment
thisLeedsSlider = LeedsSlider.trialList[0]  # so we can initialise stimuli with some values
# abbreviate parameter names if possible (e.g. rgb = thisLeedsSlider.rgb)
if thisLeedsSlider != None:
    for paramName in thisLeedsSlider:
        exec('{} = thisLeedsSlider[paramName]'.format(paramName))

for thisLeedsSlider in LeedsSlider:
    currentLoop = LeedsSlider
    # abbreviate parameter names if possible (e.g. rgb = thisLeedsSlider.rgb)
    if thisLeedsSlider != None:
        for paramName in thisLeedsSlider:
            exec('{} = thisLeedsSlider[paramName]'.format(paramName))
    
    # --- Prepare to start Routine "SliderQ" ---
    continueRoutine = True
    routineForceEnded = False
    # update component parameters for each repeat
    Text.setText(Item)
    Slider.reset()
    SliderText1.setText(Answer1)
    SliderText2.setText(Answer2)
    buttonWeiter_2.setText(Buttontext)
    # keep track of which components have finished
    SliderQComponents = [LEEDS_2, Text, Slider, SliderText1, SliderText2, buttonWeiter_2, ContinueBackText_5]
    for thisComponent in SliderQComponents:
        thisComponent.tStart = None
        thisComponent.tStop = None
        thisComponent.tStartRefresh = None
        thisComponent.tStopRefresh = None
        if hasattr(thisComponent, 'status'):
            thisComponent.status = NOT_STARTED
    # reset timers
    t = 0
    _timeToFirstFrame = win.getFutureFlipTime(clock="now")
    frameN = -1
    
    # --- Run Routine "SliderQ" ---
    while continueRoutine:
        # get current time
        t = routineTimer.getTime()
        tThisFlip = win.getFutureFlipTime(clock=routineTimer)
        tThisFlipGlobal = win.getFutureFlipTime(clock=None)
        frameN = frameN + 1  # number of completed frames (so 0 is the first frame)
        # update/draw components on each frame
        
        # *LEEDS_2* updates
        if LEEDS_2.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            LEEDS_2.frameNStart = frameN  # exact frame index
            LEEDS_2.tStart = t  # local t and not account for scr refresh
            LEEDS_2.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(LEEDS_2, 'tStartRefresh')  # time at next scr refresh
            LEEDS_2.setAutoDraw(True)
        
        # *Text* updates
        if Text.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            Text.frameNStart = frameN  # exact frame index
            Text.tStart = t  # local t and not account for scr refresh
            Text.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(Text, 'tStartRefresh')  # time at next scr refresh
            Text.setAutoDraw(True)
        
        # *Slider* updates
        if Slider.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            Slider.frameNStart = frameN  # exact frame index
            Slider.tStart = t  # local t and not account for scr refresh
            Slider.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(Slider, 'tStartRefresh')  # time at next scr refresh
            Slider.setAutoDraw(True)
        
        # *SliderText1* updates
        if SliderText1.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            SliderText1.frameNStart = frameN  # exact frame index
            SliderText1.tStart = t  # local t and not account for scr refresh
            SliderText1.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(SliderText1, 'tStartRefresh')  # time at next scr refresh
            SliderText1.setAutoDraw(True)
        
        # *SliderText2* updates
        if SliderText2.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            SliderText2.frameNStart = frameN  # exact frame index
            SliderText2.tStart = t  # local t and not account for scr refresh
            SliderText2.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(SliderText2, 'tStartRefresh')  # time at next scr refresh
            SliderText2.setAutoDraw(True)
        
        # *buttonWeiter_2* updates
        if buttonWeiter_2.status == NOT_STARTED and Slider.rating:
            # keep track of start time/frame for later
            buttonWeiter_2.frameNStart = frameN  # exact frame index
            buttonWeiter_2.tStart = t  # local t and not account for scr refresh
            buttonWeiter_2.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(buttonWeiter_2, 'tStartRefresh')  # time at next scr refresh
            buttonWeiter_2.setAutoDraw(True)
        if buttonWeiter_2.status == STARTED:
            # check whether buttonWeiter_2 has been pressed
            if buttonWeiter_2.isClicked:
                if not buttonWeiter_2.wasClicked:
                    buttonWeiter_2.timesOn.append(buttonWeiter_2.buttonClock.getTime()) # store time of first click
                    buttonWeiter_2.timesOff.append(buttonWeiter_2.buttonClock.getTime()) # store time clicked until
                else:
                    buttonWeiter_2.timesOff[-1] = buttonWeiter_2.buttonClock.getTime() # update time clicked until
                if not buttonWeiter_2.wasClicked:
                    continueRoutine = False  # end routine when buttonWeiter_2 is clicked
                    None
                buttonWeiter_2.wasClicked = True  # if buttonWeiter_2 is still clicked next frame, it is not a new click
            else:
                buttonWeiter_2.wasClicked = False  # if buttonWeiter_2 is clicked next frame, it is a new click
        else:
            buttonWeiter_2.wasClicked = False  # if buttonWeiter_2 is clicked next frame, it is a new click
        
        # *ContinueBackText_5* updates
        if ContinueBackText_5.status == NOT_STARTED and tThisFlip >= 0.0-frameTolerance:
            # keep track of start time/frame for later
            ContinueBackText_5.frameNStart = frameN  # exact frame index
            ContinueBackText_5.tStart = t  # local t and not account for scr refresh
            ContinueBackText_5.tStartRefresh = tThisFlipGlobal  # on global time
            win.timeOnFlip(ContinueBackText_5, 'tStartRefresh')  # time at next scr refresh
            ContinueBackText_5.setAutoDraw(True)
        
        # check for quit (typically the Esc key)
        if endExpNow or defaultKeyboard.getKeys(keyList=["escape"]):
            core.quit()
        
        # check if all components have finished
        if not continueRoutine:  # a component has requested a forced-end of Routine
            routineForceEnded = True
            break
        continueRoutine = False  # will revert to True if at least one component still running
        for thisComponent in SliderQComponents:
            if hasattr(thisComponent, "status") and thisComponent.status != FINISHED:
                continueRoutine = True
                break  # at least one component has not yet finished
        
        # refresh the screen
        if continueRoutine:  # don't flip if this routine is over or we'll get a blank screen
            win.flip()
    
    # --- Ending Routine "SliderQ" ---
    for thisComponent in SliderQComponents:
        if hasattr(thisComponent, "setAutoDraw"):
            thisComponent.setAutoDraw(False)
    LeedsSlider.addData('Slider.response', Slider.getRating())
    # the Routine "SliderQ" was not non-slip safe, so reset the non-slip timer
    routineTimer.reset()
    thisExp.nextEntry()
    
# completed 1.0 repeats of 'LeedsSlider'

# get names of stimulus parameters
if LeedsSlider.trialList in ([], [None], None):
    params = []
else:
    params = LeedsSlider.trialList[0].keys()
# save data for this loop
LeedsSlider.saveAsExcel(filename + '.xlsx', sheetName='LeedsSlider',
    stimOut=params,
    dataOut=['n','all_mean','all_std', 'all_raw'])

# --- End experiment ---
# Flip one final time so any remaining win.callOnFlip() 
# and win.timeOnFlip() tasks get executed before quitting
win.flip()

# these shouldn't be strictly necessary (should auto-save)
thisExp.saveAsWideText(filename+'.csv', delim='auto')
thisExp.saveAsPickle(filename)
logging.flush()
# make sure everything is closed down
if eyetracker:
    eyetracker.setConnectionState(False)
thisExp.abort()  # or data files will save again on exit
win.close()
core.quit()

expInof()
# Out:
# 3128.5751 	WARNING 	User requested fullscreen with size [1920 1080], but screen is actually [1280, 800]. Using actual size
# ioHub Server Process Completed With Code:  0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\noemi\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
